# %%
# !where python
# !python --version
# Out:
# f:\code space of everything\Minimind-From-Scratch\.conda\python.exe
# D:\anaconda3\python.exe
# C:\Users\fzy\AppData\Local\Microsoft\WindowsApps\python.exe
# Python 3.10.19

# %%
conda install -p f:\code space of everything\Minimind-From-Scratch\.conda ipykernel --update-deps --force-reinstall
# Out:
# 运行具有“.conda (Python 3.10.19)”的单元格需要ipykernel包。
#
# 将“ipykernel”安装到 Python 环境中。
#
# 命令:“conda install -p f:\code space of everything\Minimind-From-Scratch\.conda ipykernel --update-deps --force-reinstall”
